# %% [markdown]
# Comparison of Stillwell and Gabay heuristics on Caprara, Stillwell, and Gabay datasets...

# %% [markdown]
# ## Caprara Problem Sets

# %%
from itertools import chain, cycle, product

import pandas as pd

from vectorpack import generate_problem

input_vars = [ 'cls', 'num_items' ]
paramsets = [
    { 'cls' : range(1, 10), 'num_items': [ 25, 50, 100, 200 ], 'i' : range(10)},
    { 'cls' : [10],         'num_items': [ 24, 51, 99, 201 ], 'i' : range(10)}    
]

problems = pd.DataFrame(
    [dict([('cls', cls), ('num_items', num_items), ('i', i)] +
    list(generate_problem(family='caprara2001lba', seed="seed: {:d} {:d} {:d}".format(cls, num_items, i), 
                          cls=cls, num_items=num_items).items()))
    for cls, num_items, i in  chain(*[product(paramset['cls'], paramset['num_items'], paramset['i'])
                                     for paramset in paramsets])]
)
problems.describe()
# Out:
#               cls           i   num_items
# count  400.000000  400.000000  400.000000
# mean     5.500000    4.500000   93.750000
# std      2.875878    2.875878   67.155134
# min      1.000000    0.000000   24.000000
# 25%      3.000000    2.000000   43.750000
# 50%      5.500000    4.500000   75.000000
# 75%      8.000000    7.000000  125.000000
# max     10.000000    9.000000  201.000000
#
# [8 rows x 3 columns]

# %%
from vectorpack import pack_vectors

algo_family = 'stillwell_current'

algo_name_format = '{pack:<13s} {select:<10s} {itemsort:<10s} {binsort:<10s}'

algo_params = {
    'pack' : [ 'pack_by_items', 'pack_by_bins' ],
    'select' : [ 'none', 'a:sum', 'd:sum', 'a:max', 'd:max', 'a:maxdiff', 'd:maxdiff', 'a:imaxratio', 'd:imaxratio',
                 'a:lnorm', 'd:lnorm', 'pp', 'pp:w=2', 'cp:w=1', 'cp:w=2' ],
    'itemsort' : [ 'none', 'a:sum', 'd:sum', 'a:max', 'd:max', 'a:maxdiff', 'd:maxdiff', 'a:imaxratio', 'd:imaxratio',
                   'a:lnorm', 'd:lnorm' ],
    'binsort' : [ 'none', 'a:sum', 'd:sum', 'a:max', 'd:max', 'a:maxdiff', 'd:maxdiff', 'a:imaxratio', 'd:imaxratio',
                  'a:lnorm', 'd:lnorm' ],
}

algo_vars = list(algo_params)

algos = map(dict, product(*[[(name, value) for value in values] for name, values in algo_params.items()]))

algos = [
    { 'pack' : 'pack_by_items', 'select' : 'none',      'itemsort' : 'none',       'binsort' : 'none' },
    { 'pack' : 'pack_by_items', 'select' : 'a:sum',     'itemsort' : 'd:sum',      'binsort' : 'a:sum' },
    { 'pack' : 'pack_by_items', 'select' : 'a:maxdiff', 'itemsort' : 'd:lnorm',    'binsort' : 'd:maxratio' },
    { 'pack' : 'pack_by_items', 'select' : 'pp',        'itemsort' : 'd:maxratio', 'binsort' : 'd:maxratio' },
    { 'pack' : 'pack_by_bins',  'select' : 'none',      'itemsort' : 'none',       'binsort' : 'none' },
    { 'pack' : 'pack_by_bins',  'select' : 'a:sum',     'itemsort' : 'd:sum',      'binsort' : 'a:sum' },
    { 'pack' : 'pack_by_bins',  'select' : 'a:maxdiff', 'itemsort' : 'd:lnorm',    'binsort' : 'd:maxratio' },
    { 'pack' : 'pack_by_bins',  'select' : 'pp',        'itemsort' : 'd:maxratio', 'binsort' : 'd:maxratio' },
    { 'pack' : 'pack_by_bins',  'select' : 'd:sum',     'itemsort' : 'a:sum',      'binsort' : 'd:sum' },
]

solutions1 = pd.DataFrame([dict([('probidx', idx_problem[0]), ('algo_family', algo_family),
                                ('algo_name', algo_name_format.format(**algo))] +
                               list(pack_vectors(problem=idx_problem[1], family=algo_family, **algo).items())) 
                          for idx_problem, algo in product(problems.iterrows(), algos)])

solutions1.describe()
# Out:
#        algo-runtime     bincount  failcount      probidx  total-runtime  \
# count   3600.000000  3600.000000       3600  3600.000000    3600.000000
# mean       0.134020    37.232778          0   199.500000       0.134058
# std        0.168973    33.222786          0   115.485734       0.168978
# min        0.003374     2.000000          0     0.000000       0.003403
# 25%        0.012973    13.000000          0    99.750000       0.013015
# 50%        0.048738    26.000000          0   199.500000       0.048777
# 75%        0.185289    55.000000          0   299.250000       0.185333
# max        0.706236   157.000000          0   399.000000       0.706291
#
#       verified
# count     3600
# mean         1
# std          0
# min       True
# 25%          1
# 50%          1
# 75%          1
# max       True
#
# [8 rows x 6 columns]

# %%
algo_family = 'gabay2013vsv'

algo_name_format = '{heuristic:<16s} {item_measure:<20s} {bin_measure:<20s}'

algo_params = {
    'heuristic' : [ 'bfd_item_centric', 'bfd_bin_centric', 'bin_balancing' ],
    'item_measure' : [ 'do_nothing', 'shuffleItemsOnce', 'staticItemsOneOverC', 'staticItemsOneOverR', 
                       'staticItemsROverC', 'shuffleItems', 'dynamicItemsOneOverC', 'dynamicItemsOneOverR', 
                       'dynamicItemsROverC' ],
    'bin_measure' : [ 'do_nothing', 'shuffleBinsOnce', 'staticBinsOneOverC', 'staticBinsOneOverR', 
                       'staticBinsROverC', 'shuffleBins', 'dynamicBinsOneOverC', 'dynamicBinsOneOverR', 
                       'dynamicBinsROverC' ],
}

algo_vars = list(algo_params)

algos = map(dict, product(*[[(name, value) for value in values] for name, values in algo_params.items()]))

algos = [
    { 'heuristic' : 'bfd_item_centric', 'item_measure' : 'do_nothing', 'bin_measure' : 'do_nothing' },
    { 'heuristic' : 'bfd_item_centric', 'item_measure' : 'shuffleItemsOnce', 'bin_measure' : 'shuffleBinsOnce' },
    { 'heuristic' : 'bfd_item_centric', 'item_measure' : 'shuffleItems', 'bin_measure' : 'shuffleBins' },
    { 'heuristic' : 'bfd_item_centric', 'item_measure' : 'staticItemsOneOverC', 'bin_measure' : 'staticBinsOneOverC' },
    { 'heuristic' : 'bfd_item_centric', 'item_measure' : 'staticItemsOneOverR', 'bin_measure' : 'staticBinsOneOverR' },
    { 'heuristic' : 'bfd_item_centric', 'item_measure' : 'staticItemsROverC', 'bin_measure' : 'staticBinsROverC' },
    { 'heuristic' : 'bfd_item_centric', 'item_measure' : 'dynamicItemsOneOverC', 'bin_measure' : 'dynamicBinsOneOverC' },
    { 'heuristic' : 'bfd_item_centric', 'item_measure' : 'dynamicItemsOneOverR', 'bin_measure' : 'dynamicBinsOneOverR' },
    { 'heuristic' : 'bfd_item_centric', 'item_measure' : 'dynamicItemsROverC', 'bin_measure' : 'dynamicBinsROverC' },
    { 'heuristic' : 'bfd_bin_centric', 'item_measure' : 'do_nothing', 'bin_measure' : 'do_nothing' },
    { 'heuristic' : 'bfd_bin_centric', 'item_measure' : 'shuffleItemsOnce', 'bin_measure' : 'shuffleBinsOnce' },
    { 'heuristic' : 'bfd_bin_centric', 'item_measure' : 'shuffleItems', 'bin_measure' : 'shuffleBins' },
    { 'heuristic' : 'bfd_bin_centric', 'item_measure' : 'staticItemsOneOverC', 'bin_measure' : 'staticBinsOneOverC' },
    { 'heuristic' : 'bfd_bin_centric', 'item_measure' : 'staticItemsOneOverR', 'bin_measure' : 'staticBinsOneOverR' },
    { 'heuristic' : 'bfd_bin_centric', 'item_measure' : 'staticItemsROverC', 'bin_measure' : 'staticBinsROverC' },
    { 'heuristic' : 'bfd_bin_centric', 'item_measure' : 'dynamicItemsOneOverC', 'bin_measure' : 'dynamicBinsOneOverC' },
    { 'heuristic' : 'bfd_bin_centric', 'item_measure' : 'dynamicItemsOneOverR', 'bin_measure' : 'dynamicBinsOneOverR' },
    { 'heuristic' : 'bfd_bin_centric', 'item_measure' : 'dynamicItemsROverC', 'bin_measure' : 'dynamicBinsROverC' },
]

solutions2 = pd.DataFrame([dict([('probidx', idx_problem[0]), ('algo_family', algo_family),
                                ('algo_name', algo_name_format.format(**algo))] +
                               list(pack_vectors(problem=idx_problem[1], family=algo_family, **algo).items())) 
                          for idx_problem, algo in product(problems.iterrows(), algos)])

solutions2.describe()
# Out:
#        algo-runtime     bincount  failcount      probidx  total-runtime  \
# count   7200.000000  7200.000000       7200  7200.000000    7200.000000
# mean       0.016309    37.408472          0   199.500000       0.016662
# std        0.030291    33.896572          0   115.477713       0.030460
# min        0.000276     2.000000          0     0.000000       0.000366
# 25%        0.001407    13.000000          0    99.750000       0.001559
# 50%        0.004637    26.000000          0   199.500000       0.004911
# 75%        0.016939    55.000000          0   299.250000       0.017583
# max        0.156329   176.000000          0   399.000000       0.156954
#
#       verified
# count     7200
# mean         1
# std          0
# min       True
# 25%          1
# 50%          1
# 75%          1
# max       True
#
# [8 rows x 6 columns]

# %%
solutions = pd.concat([solutions1, solutions2])
solutions.describe()
# Out:
#        algo-runtime      bincount  failcount       probidx  total-runtime  \
# count  10800.000000  10800.000000      10800  10800.000000   10800.000000
# mean       0.055546     37.349907          0    199.500000       0.055794
# std        0.114920     33.672038          0    115.475039       0.114881
# min        0.000276      2.000000          0      0.000000       0.000366
# 25%        0.002134     13.000000          0     99.750000       0.002238
# 50%        0.008763     26.000000          0    199.500000       0.008869
# 75%        0.034125     55.000000          0    299.250000       0.034363
# max        0.706236    176.000000          0    399.000000       0.706291
#
#       verified
# count    10800
# mean         1
# std          0
# min       True
# 25%          1
# 50%          1
# 75%          1
# max       True
#
# [8 rows x 6 columns]

# %%
solutions.groupby('algo_name')[['bincount', 'algo-runtime', 'total-runtime']].mean()
# Out:
#                                                             bincount  \
# algo_name
# bfd_bin_centric  do_nothing           do_nothing             36.4450
# bfd_bin_centric  dynamicItemsOneOverC dynamicBinsOneOverC    34.9925
# bfd_bin_centric  dynamicItemsOneOverR dynamicBinsOneOverR    36.0600
# bfd_bin_centric  dynamicItemsROverC   dynamicBinsROverC      34.8125
# bfd_bin_centric  shuffleItems         shuffleBins            37.8300
# bfd_bin_centric  shuffleItemsOnce     shuffleBinsOnce        36.7500
# bfd_bin_centric  staticItemsOneOverC  staticBinsOneOverC     34.9100
# bfd_bin_centric  staticItemsOneOverR  staticBinsOneOverR     35.0825
# bfd_bin_centric  staticItemsROverC    staticBinsROverC       35.0200
# bfd_item_centric do_nothing           do_nothing             36.4450
# bfd_item_centric dynamicItemsOneOverC dynamicBinsOneOverC    35.0575
# bfd_item_centric dynamicItemsOneOverR dynamicBinsOneOverR    36.2950
# bfd_item_centric dynamicItemsROverC   dynamicBinsROverC      34.8425
# bfd_item_centric shuffleItems         shuffleBins            67.0175
# bfd_item_centric shuffleItemsOnce     shuffleBinsOnce        36.7800
# bfd_item_centric staticItemsOneOverC  staticBinsOneOverC     34.9100
# bfd_item_centric staticItemsOneOverR  staticBinsOneOverR     35.0825
# bfd_item_centric staticItemsROverC    staticBinsROverC       35.0200
# pack_by_bins  a:maxdiff  d:lnorm    d:maxratio               36.7250
# pack_by_bins  a:sum      d:sum      a:sum                    34.9025
# pack_by_bins  d:sum      a:sum      d:sum                    41.3225
# pack_by_bins  none       none       none                     36.4450
# pack_by_bins  pp         d:maxratio d:maxratio               37.1400
# pack_by_items a:maxdiff  d:lnorm    d:maxratio               40.0675
# pack_by_items a:sum      d:sum      a:sum                    34.9075
# pack_by_items none       none       none                     36.4450
# pack_by_items pp         d:maxratio d:maxratio               37.1400
#
#                                                             algo-runtime  \
# algo_name
# bfd_bin_centric  do_nothing           do_nothing                0.004957
# bfd_bin_centric  dynamicItemsOneOverC dynamicBinsOneOverC       0.036189
# bfd_bin_centric  dynamicItemsOneOverR dynamicBinsOneOverR       0.025404
# bfd_bin_centric  dynamicItemsROverC   dynamicBinsROverC         0.037139
# bfd_bin_centric  shuffleItems         shuffleBins               0.008079
# bfd_bin_centric  shuffleItemsOnce     shuffleBinsOnce           0.005172
# bfd_bin_centric  staticItemsOneOverC  staticBinsOneOverC        0.005972
# bfd_bin_centric  staticItemsOneOverR  staticBinsOneOverR        0.005955
# bfd_bin_centric  staticItemsROverC    staticBinsROverC          0.006071
# bfd_item_centric do_nothing           do_nothing                0.005170
# bfd_item_centric dynamicItemsOneOverC dynamicBinsOneOverC       0.040616
# bfd_item_centric dynamicItemsOneOverR dynamicBinsOneOverR       0.032451
# bfd_item_centric dynamicItemsROverC   dynamicBinsROverC         0.049250
# bfd_item_centric shuffleItems         shuffleBins               0.008102
# bfd_item_centric shuffleItemsOnce     shuffleBinsOnce           0.005475
# bfd_item_centric staticItemsOneOverC  staticBinsOneOverC        0.005813
# bfd_item_centric staticItemsOneOverR  staticBinsOneOverR        0.005809
# bfd_item_centric staticItemsROverC    staticBinsROverC          0.005937
# pack_by_bins  a:maxdiff  d:lnorm    d:maxratio                  0.107998
# pack_by_bins  a:sum      d:sum      a:sum                       0.112447
# pack_by_bins  d:sum      a:sum      d:sum                       0.115850
# pack_by_bins  none       none       none                        0.079645
# pack_by_bins  pp         d:maxratio d:maxratio                  0.125640
# pack_by_items a:maxdiff  d:lnorm    d:maxratio                  0.167796
# pack_by_items a:sum      d:sum      a:sum                       0.173861
# pack_by_items none       none       none                        0.115401
# pack_by_items pp         d:maxratio d:maxratio                  0.207541
#
#                                                             total-runtime
# algo_name
# bfd_bin_centric  do_nothing           do_nothing                 0.005245
# bfd_bin_centric  dynamicItemsOneOverC dynamicBinsOneOverC        0.036483
# bfd_bin_centric  dynamicItemsOneOverR dynamicBinsOneOverR        0.025698
# bfd_bin_centric  dynamicItemsROverC   dynamicBinsROverC          0.037436
# bfd_bin_centric  shuffleItems         shuffleBins                0.008649
# bfd_bin_centric  shuffleItemsOnce     shuffleBinsOnce            0.005540
# bfd_bin_centric  staticItemsOneOverC  staticBinsOneOverC         0.006261
# bfd_bin_centric  staticItemsOneOverR  staticBinsOneOverR         0.006244
# bfd_bin_centric  staticItemsROverC    staticBinsROverC           0.006359
# bfd_item_centric do_nothing           do_nothing                 0.005575
# bfd_item_centric dynamicItemsOneOverC dynamicBinsOneOverC        0.040906
# bfd_item_centric dynamicItemsOneOverR dynamicBinsOneOverR        0.032742
# bfd_item_centric dynamicItemsROverC   dynamicBinsROverC          0.049541
# bfd_item_centric shuffleItems         shuffleBins                0.008397
# bfd_item_centric shuffleItemsOnce     shuffleBinsOnce            0.005763
# bfd_item_centric staticItemsOneOverC  staticBinsOneOverC         0.006104
# bfd_item_centric staticItemsOneOverR  staticBinsOneOverR         0.006101
# bfd_item_centric staticItemsROverC    staticBinsROverC           0.006864
# pack_by_bins  a:maxdiff  d:lnorm    d:maxratio                   0.108037
# pack_by_bins  a:sum      d:sum      a:sum                        0.112485
# pack_by_bins  d:sum      a:sum      d:sum                        0.115891
# pack_by_bins  none       none       none                         0.079681
# pack_by_bins  pp         d:maxratio d:maxratio                   0.125679
# pack_by_items a:maxdiff  d:lnorm    d:maxratio                   0.167836
# pack_by_items a:sum      d:sum      a:sum                        0.173899
# pack_by_items none       none       none                         0.115437
# pack_by_items pp         d:maxratio d:maxratio                   0.207580
#
# [27 rows x 3 columns]
