# %% [markdown]
# # *Note*: This Notebook uses Python3

# %%
from itertools import chain, cycle, product

import pandas as pd

from vectorpack.genprob import generate_problem_caprara

input_vars = [ 'cls', 'num_items' ]
paramsets = [
    { 'cls' : range(1, 10), 'num_items': [ 25, 50, 100, 200 ], 'i' : range(10)},
    { 'cls' : [10],         'num_items': [ 24, 51, 99, 201 ], 'i' : range(10)}    
]

problems = pd.DataFrame(
    [dict([('cls', cls), ('num_items', num_items), ('i', i)] +
    list(generate_problem_caprara(seed="seed: {:d} {:d} {:d}".format(cls, num_items, i), 
                                  cls=cls, num_items=num_items).items()))
    for cls, num_items, i in  chain(*[product(paramset['cls'], paramset['num_items'], paramset['i'])
                                     for paramset in paramsets])]
)

problems
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 0 to 399
# Data columns (total 8 columns):
# args         400  non-null values
# argshash     400  non-null values
# bins         400  non-null values
# cls          400  non-null values
# i            400  non-null values
# items        400  non-null values
# note         400  non-null values
# num_items    400  non-null values
# dtypes: int64(3), object(5)

# %%
from vectorpack.bounds import bound_lc

idxs, bounds = zip(*[(idx, bound_lc(problem=problem)) for idx, problem in problems.iterrows()])
problems['bound_lc'] = pd.Series(index=idxs, data=bounds)

problems
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 400 entries, 0 to 399
# Data columns (total 9 columns):
# args         400  non-null values
# argshash     400  non-null values
# bins         400  non-null values
# cls          400  non-null values
# i            400  non-null values
# items        400  non-null values
# note         400  non-null values
# num_items    400  non-null values
# bound_lc     400  non-null values
# dtypes: int64(4), object(5)

# %%
from vectorpack import pack_vectors

algo_params = {
    'pack' : [ 'pack_by_items', 'pack_by_bins' ],
    'select' : [ 'none', 'a:sum', 'd:sum', 'a:max', 'd:max', 'a:maxdiff', 'd:maxdiff', 'a:imaxratio', 'd:imaxratio',
                 'a:lnorm', 'd:lnorm', 'pp', 'pp:w=2', 'cp:w=1', 'cp:w=2' ],
    'itemsort' : [ 'none', 'a:sum', 'd:sum', 'a:max', 'd:max', 'a:maxdiff', 'd:maxdiff', 'a:imaxratio', 'd:imaxratio',
                   'a:lnorm', 'd:lnorm' ],
    'binsort' : [ 'none', 'a:sum', 'd:sum', 'a:max', 'd:max', 'a:maxdiff', 'd:maxdiff', 'a:imaxratio', 'd:imaxratio',
                  'a:lnorm', 'd:lnorm' ],
}

algo_name_format = '{pack:<13s} {select:<10s} {itemsort:<10s} {binsort:<10s}'

algos = map(dict, product(*[[(name, value) for value in values] for name, values in algo_params.items()]))

algos = [
    { 'pack' : 'pack_by_items', 'select' : 'none',      'itemsort' : 'none',       'binsort' : 'none' },
    { 'pack' : 'pack_by_items', 'select' : 'a:sum',     'itemsort' : 'd:sum',      'binsort' : 'a:sum' },
    { 'pack' : 'pack_by_items', 'select' : 'a:lnorm',   'itemsort' : 'd:lnorm',    'binsort' : 'a:lnorm' },
    { 'pack' : 'pack_by_items', 'select' : 'a:maxdiff', 'itemsort' : 'd:lnorm',    'binsort' : 'd:maxratio' },
    { 'pack' : 'pack_by_items', 'select' : 'pp',        'itemsort' : 'd:maxratio', 'binsort' : 'd:maxratio' },
    { 'pack' : 'pack_by_bins',  'select' : 'none',      'itemsort' : 'none',       'binsort' : 'none' },
    { 'pack' : 'pack_by_bins',  'select' : 'a:sum',     'itemsort' : 'd:sum',      'binsort' : 'a:sum' },
    { 'pack' : 'pack_by_bins',  'select' : 'a:lnorm',   'itemsort' : 'd:lnorm',    'binsort' : 'a:lnorm' },
    { 'pack' : 'pack_by_bins',  'select' : 'a:maxdiff', 'itemsort' : 'd:lnorm',    'binsort' : 'd:maxratio' },
    { 'pack' : 'pack_by_bins',  'select' : 'pp',        'itemsort' : 'd:maxratio', 'binsort' : 'd:maxratio' },
]

solutions = pd.DataFrame([dict([('probidx', idx_problem[0])] +
                               list(pack_vectors(problem=idx_problem[1], **algo).items())) 
                          for idx_problem, algo in product(problems.iterrows(), algos)])

solutions
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 14 columns):
# bincount            4000  non-null values
# binsort             4000  non-null values
# datetime            4000  non-null values
# failcount           4000  non-null values
# itemsort            4000  non-null values
# mapping             4000  non-null values
# pack                4000  non-null values
# probidx             4000  non-null values
# problem-argshash    4000  non-null values
# runtime             4000  non-null values
# select              4000  non-null values
# solver-githash      4000  non-null values
# split               4000  non-null values
# verified            4000  non-null values
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(4), object(7)

# %%
data = pd.merge(problems, solutions, left_index=True, right_on='probidx')

data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4000 entries, 0 to 3999
# Data columns (total 23 columns):
# args                4000  non-null values
# argshash            4000  non-null values
# bins                4000  non-null values
# cls                 4000  non-null values
# i                   4000  non-null values
# items               4000  non-null values
# note                4000  non-null values
# num_items           4000  non-null values
# bound_lc            4000  non-null values
# bincount            4000  non-null values
# binsort             4000  non-null values
# datetime            4000  non-null values
# failcount           4000  non-null values
# itemsort            4000  non-null values
# mapping             4000  non-null values
# pack                4000  non-null values
# probidx             4000  non-null values
# problem-argshash    4000  non-null values
# runtime             4000  non-null values
# select              4000  non-null values
# solver-githash      4000  non-null values
# split               4000  non-null values
# verified            4000  non-null values
# dtypes: bool(1), datetime64[ns](1), float64(1), int64(8), object(12)

# %% [markdown]
# Here, I want to

# %%
for algo in algos:
    print(algo_name_format.format(**algo))

for (cls, num_items), probset in problems.groupby([ 'cls', 'num_items' ]):
    print('{:>2d} | {:>3d} | {:>6.2f}'.format(cls, num_items, probset['bound_lc'].mean()), end='')
    for algo, sols in data[(data['cls'] == cls) & (data['num_items'] == num_items)].groupby(algo_params):
        print(' || {:>6.2f} | {:>5.2f}'.format(sols['bincount'].mean(), sols['runtime'].mean()), end='')

    print(' ||')
# Out:
# pack_by_items none       none       none
# pack_by_items a:sum      d:sum      a:sum
# pack_by_items a:lnorm    d:lnorm    a:lnorm
# pack_by_items a:maxdiff  d:lnorm    d:maxratio
# pack_by_items pp         d:maxratio d:maxratio
# pack_by_bins  none       none       none
# pack_by_bins  a:sum      d:sum      a:sum
# pack_by_bins  a:lnorm    d:lnorm    a:lnorm
# pack_by_bins  a:maxdiff  d:lnorm    d:maxratio
# pack_by_bins  pp         d:maxratio d:maxratio
#  1 |  25 |   6.80 ||   7.20 |  0.01 ||   7.60 |  0.01 ||   7.40 |  0.01 ||   7.50 |  0.00 ||   7.40 |  0.01 ||   7.50 |  0.01 ||  10.50 |  0.01 ||   7.40 |  0.01 ||   7.50 |  0.01 ||  10.10 |  0.01 ||
#  9 |  50 |  13.40 ||  14.60 |  0.03 ||  15.80 |  0.03 ||  15.30 |  0.02 ||  15.60 |  0.02 ||  15.30 |  0.03 ||  15.20 |  0.06 ||  17.70 |  0.04 ||  15.30 |  0.04 ||  15.60 |  0.02 ||  16.10 |  0.05 ||
#  9 | 100 |  25.70 ||  27.70 |  0.13 ||  28.90 |  0.10 ||  28.10 |  0.09 ||  29.30 |  0.06 ||  28.50 |  0.11 ||  28.40 |  0.22 ||  34.80 |  0.16 ||  28.10 |  0.15 ||  29.30 |  0.09 ||  31.90 |  0.20 ||
#  9 | 200 |  51.60 ||  54.30 |  0.49 ||  57.50 |  0.37 ||  56.60 |  0.37 ||  58.40 |  0.22 ||  56.20 |  0.44 ||  56.30 |  0.86 ||  67.30 |  0.63 ||  56.60 |  0.61 ||  58.40 |  0.34 ||  62.20 |  0.80 ||
# 10 |  24 |   8.00 ||   9.20 |  0.01 ||   9.90 |  0.01 ||   9.30 |  0.01 ||   8.50 |  0.00 ||   9.40 |  0.01 ||   9.40 |  0.01 ||  10.50 |  0.01 ||   9.30 |  0.01 ||   8.50 |  0.01 ||  11.20 |  0.01 ||
# 10 |  51 |  17.00 ||  19.20 |  0.04 ||  20.40 |  0.03 ||  19.20 |  0.03 ||  18.50 |  0.02 ||  19.90 |  0.03 ||  19.20 |  0.06 ||  21.20 |  0.04 ||  19.20 |  0.04 ||  18.50 |  0.02 ||  22.20 |  0.05 ||
# 10 |  99 |  33.00 ||  36.30 |  0.12 ||  38.70 |  0.09 ||  36.50 |  0.09 ||  35.50 |  0.06 ||  38.00 |  0.11 ||  36.40 |  0.21 ||  38.60 |  0.15 ||  36.50 |  0.15 ||  35.50 |  0.09 ||  41.80 |  0.19 ||
# 10 | 201 |  67.00 ||  71.80 |  0.50 ||  76.90 |  0.38 ||  72.00 |  0.38 ||  71.90 |  0.24 ||  76.20 |  0.44 ||  72.00 |  0.84 ||  74.70 |  0.63 ||  72.00 |  0.61 ||  71.90 |  0.35 ||  83.10 |  0.80 ||

# %%
from matplotlib import pyplot as plt, rcParams

rcParams['savefig.dpi'] = 108

for cls in range(1, 11):
    fig = plt.figure()
    ax = fig.add_subplot(111)

    for algo, sols_by_algo in data[(data['cls'] == cls)].groupby(algo_params):
        sols_by_algo.groupby('num_items')['bincount'].mean().plot(ax=ax, label=algo)

    problems[(problems['cls'] == cls)].groupby('num_items')['bound_lc'].mean().plot(ax=ax, label='bound_lc')

    ax.set_title('class {:d}'.format(cls))
    ax.set_xlabel('number of items')
    ax.set_ylabel('bins required')
   
    for l, ms in zip(ax.lines, cycle('>^+*')):
        l.set_marker(ms)
        
    plt.xlim([25, 200])
    plt.legend(loc='upper left', bbox_to_anchor=(1.05, 1))
    plt.show()

# %%
for (cls, num_items), sols in data.groupby(['cls', 'num_items']):
    print("class: {:d}, num_items: {:d}".format(cls, num_items))
    print(sols.groupby(algo_params)[['bincount', 'runtime']].mean().sort(columns=['bincount', 'runtime']))
    print()
# Out:
# class: 1, num_items: 25
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm          7.2  0.009416
#               a:sum     d:sum      a:sum            7.4  0.006896
#               pp        d:maxratio d:maxratio       7.4  0.008862
# pack_by_items a:sum     d:sum      a:sum            7.4  0.012656
# pack_by_bins  none      none       none             7.5  0.004169
# pack_by_items none      none       none             7.5  0.006348
#               a:lnorm   d:lnorm    a:lnorm          7.5  0.014947
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio       7.6  0.007483
# pack_by_items pp        d:maxratio d:maxratio      10.1  0.014051
#               a:maxdiff d:lnorm    d:maxratio      10.5  0.011473
# class: 1, num_items: 50
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum           14.3  0.025019
#               a:lnorm   d:lnorm    a:lnorm         14.3  0.033882
# pack_by_items a:sum     d:sum      a:sum           14.3  0.039682
#               a:lnorm   d:lnorm    a:lnorm         14.3  0.057370
# pack_by_bins  pp        d:maxratio d:maxratio      14.4  0.030777
#               none      none       none            14.5  0.015053
# pack_by_items none      none       none            14.5  0.022599
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      15.0  0.025820
# pack_by_items pp        d:maxratio d:maxratio      19.1  0.053251
#               a:maxdiff d:lnorm    d:maxratio      20.6  0.042805
#
# class: 1, num_items: 100
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         27.1  0.126981
#               a:sum     d:sum      a:sum           27.9  0.093549
# pack_by_items a:sum     d:sum      a:sum           27.9  0.155417
#               a:lnorm   d:lnorm    a:lnorm         27.9  0.219163
# pack_by_bins  pp        d:maxratio d:maxratio      28.0  0.114257
#               a:maxdiff d:lnorm    d:maxratio      28.6  0.095047
#               none      none       none            29.2  0.056922
# pack_by_items none      none       none            29.2  0.087514
#               a:maxdiff d:lnorm    d:maxratio      32.3  0.161003
#               pp        d:maxratio d:maxratio      37.1  0.203589
#
# class: 1, num_items: 200
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         52.9  0.492004
#               pp        d:maxratio d:maxratio      54.6  0.439224
#               a:sum     d:sum      a:sum           54.9  0.368398
# pack_by_items a:sum     d:sum      a:sum           54.9  0.608796
#               a:lnorm   d:lnorm    a:lnorm         55.1  0.864217
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      56.2  0.363228
#               none      none       none            57.5  0.223326
# pack_by_items none      none       none            57.5  0.343820
#               a:maxdiff d:lnorm    d:maxratio      61.9  0.630117
#               pp        d:maxratio d:maxratio      70.7  0.795801
#
# class: 2, num_items: 25
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum           17.1  0.007446
# pack_by_items a:sum     d:sum      a:sum           17.1  0.009073
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         17.2  0.009743
# pack_by_items a:lnorm   d:lnorm    a:lnorm         17.2  0.012426
# pack_by_bins  pp        d:maxratio d:maxratio      17.9  0.008737
#               a:maxdiff d:lnorm    d:maxratio      18.0  0.007763
#               none      none       none            18.1  0.004920
# pack_by_items none      none       none            18.1  0.005802
#               pp        d:maxratio d:maxratio      18.2  0.011996
#               a:maxdiff d:lnorm    d:maxratio      18.4  0.009556
#
# class: 2, num_items: 50
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_items a:lnorm   d:lnorm    a:lnorm         32.0  0.046971
# pack_by_bins  a:sum     d:sum      a:sum           32.1  0.025586
# pack_by_items a:sum     d:sum      a:sum           32.1  0.034226
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         32.3  0.033071
#               a:maxdiff d:lnorm    d:maxratio      33.5  0.026370
#               none      none       none            33.6  0.017493
# pack_by_items none      none       none            33.6  0.021676
#               a:maxdiff d:lnorm    d:maxratio      33.9  0.035753
# pack_by_bins  pp        d:maxratio d:maxratio      34.3  0.029869
# pack_by_items pp        d:maxratio d:maxratio      34.4  0.046158
#
# class: 2, num_items: 100
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         61.6  0.121985
# pack_by_items a:lnorm   d:lnorm    a:lnorm         61.6  0.180174
# pack_by_bins  a:sum     d:sum      a:sum           61.7  0.095331
# pack_by_items a:sum     d:sum      a:sum           61.7  0.132944
#               a:maxdiff d:lnorm    d:maxratio      63.6  0.138017
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      63.7  0.096156
#               none      none       none            65.5  0.065780
# pack_by_items none      none       none            65.5  0.085120
# pack_by_bins  pp        d:maxratio d:maxratio      67.3  0.109908
# pack_by_items pp        d:maxratio d:maxratio      68.3  0.178070
# class: 2, num_items: 200
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum          118.3  0.364658
# pack_by_items a:sum     d:sum      a:sum          118.3  0.526169
#               a:lnorm   d:lnorm    a:lnorm        118.4  0.710899
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm        118.6  0.454140
# pack_by_items a:maxdiff d:lnorm    d:maxratio     121.0  0.539516
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio     123.5  0.368378
#               none      none       none           125.8  0.255649
# pack_by_items none      none       none           125.8  0.333201
# pack_by_bins  pp        d:maxratio d:maxratio     130.7  0.415524
# pack_by_items pp        d:maxratio d:maxratio     132.2  0.700563
#
# class: 3, num_items: 25
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum           16.5  0.007103
# pack_by_items a:sum     d:sum      a:sum           16.5  0.008959
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         16.5  0.009316
# pack_by_items a:lnorm   d:lnorm    a:lnorm         16.5  0.012394
# pack_by_bins  pp        d:maxratio d:maxratio      17.0  0.008728
#               none      none       none            17.2  0.004847
# pack_by_items none      none       none            17.2  0.005748
#               pp        d:maxratio d:maxratio      17.2  0.012104
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      17.3  0.007690
# pack_by_items a:maxdiff d:lnorm    d:maxratio      18.2  0.009762
#
# class: 3, num_items: 50
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_items a:lnorm   d:lnorm    a:lnorm         32.2  0.046417
# pack_by_bins  a:sum     d:sum      a:sum           32.3  0.025706
#               a:lnorm   d:lnorm    a:lnorm         32.3  0.033002
# pack_by_items a:sum     d:sum      a:sum           32.3  0.034161
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      33.9  0.026863
# pack_by_items a:maxdiff d:lnorm    d:maxratio      34.0  0.036325
# pack_by_bins  pp        d:maxratio d:maxratio      34.1  0.030706
#               none      none       none            34.3  0.017848
# pack_by_items none      none       none            34.3  0.021807
#               pp        d:maxratio d:maxratio      34.4  0.046084
#
# class: 3, num_items: 100
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum           59.3  0.094056
# pack_by_items a:sum     d:sum      a:sum           59.3  0.132911
#               a:lnorm   d:lnorm    a:lnorm         59.3  0.181637
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         59.5  0.120226
# pack_by_items a:maxdiff d:lnorm    d:maxratio      62.6  0.137747
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      63.2  0.097830
#               pp        d:maxratio d:maxratio      63.6  0.113670
# pack_by_items pp        d:maxratio d:maxratio      64.1  0.179174
# pack_by_bins  none      none       none            64.2  0.067078
# pack_by_items none      none       none            64.2  0.084867
#
# class: 3, num_items: 200
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum          117.1  0.362632
# pack_by_items a:sum     d:sum      a:sum          117.1  0.525314
#               a:lnorm   d:lnorm    a:lnorm        117.1  0.707115
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm        117.2  0.453158
# pack_by_items a:maxdiff d:lnorm    d:maxratio     121.4  0.537133
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio     123.9  0.377292
#               pp        d:maxratio d:maxratio     125.9  0.430038
#               none      none       none           126.4  0.260286
# pack_by_items none      none       none           126.4  0.335905
#               pp        d:maxratio d:maxratio     126.7  0.700844
#
# class: 4, num_items: 25
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  none      none       none             4.0  0.003804
# pack_by_items none      none       none             4.0  0.005958
# pack_by_bins  a:sum     d:sum      a:sum            4.0  0.006477
#               a:maxdiff d:lnorm    d:maxratio       4.0  0.007136
#               pp        d:maxratio d:maxratio       4.0  0.008683
#               a:lnorm   d:lnorm    a:lnorm          4.0  0.009336
# pack_by_items a:sum     d:sum      a:sum            4.0  0.010978
#               a:lnorm   d:lnorm    a:lnorm          4.0  0.015729
#               pp        d:maxratio d:maxratio       8.7  0.014729
#               a:maxdiff d:lnorm    d:maxratio       9.0  0.011863
# class: 4, num_items: 50
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum            7.0  0.023936
#               pp        d:maxratio d:maxratio       7.0  0.031091
#               a:lnorm   d:lnorm    a:lnorm          7.0  0.034085
# pack_by_items a:sum     d:sum      a:sum            7.0  0.041886
#               a:lnorm   d:lnorm    a:lnorm          7.0  0.060754
# pack_by_bins  none      none       none             7.1  0.013744
# pack_by_items none      none       none             7.1  0.022639
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio       7.2  0.025140
# pack_by_items pp        d:maxratio d:maxratio      13.7  0.056005
#               a:maxdiff d:lnorm    d:maxratio      14.0  0.044792
#
# class: 4, num_items: 100
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         13.5  0.127006
#               pp        d:maxratio d:maxratio      13.7  0.114397
#               none      none       none            13.8  0.051742
# pack_by_items none      none       none            13.8  0.087913
# pack_by_bins  a:sum     d:sum      a:sum           13.8  0.091529
#               a:maxdiff d:lnorm    d:maxratio      13.8  0.093248
# pack_by_items a:sum     d:sum      a:sum           13.8  0.162100
#               a:lnorm   d:lnorm    a:lnorm         13.8  0.232906
#               a:maxdiff d:lnorm    d:maxratio      23.1  0.169781
#               pp        d:maxratio d:maxratio      28.2  0.213273
#
# class: 4, num_items: 200
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         26.6  0.505194
#               pp        d:maxratio d:maxratio      27.0  0.444614
# pack_by_items a:lnorm   d:lnorm    a:lnorm         27.2  0.926698
# pack_by_bins  a:sum     d:sum      a:sum           27.3  0.356765
# pack_by_items a:sum     d:sum      a:sum           27.3  0.646222
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      27.4  0.361714
#               none      none       none            27.7  0.201826
# pack_by_items none      none       none            27.7  0.348697
#               pp        d:maxratio d:maxratio      49.7  0.842417
#               a:maxdiff d:lnorm    d:maxratio      50.0  0.668025
#
# class: 5, num_items: 25
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  none      none       none             2.0  0.003625
# pack_by_items none      none       none             2.0  0.005996
# pack_by_bins  a:sum     d:sum      a:sum            2.0  0.006445
#               a:maxdiff d:lnorm    d:maxratio       2.0  0.007004
#               pp        d:maxratio d:maxratio       2.0  0.008500
#               a:lnorm   d:lnorm    a:lnorm          2.0  0.009228
# pack_by_items a:sum     d:sum      a:sum            2.0  0.011098
#               a:lnorm   d:lnorm    a:lnorm          2.0  0.016073
#               pp        d:maxratio d:maxratio       4.0  0.014692
#               a:maxdiff d:lnorm    d:maxratio       7.4  0.011888
#
# class: 5, num_items: 50
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  none      none       none             4.0  0.013037
# pack_by_items none      none       none             4.0  0.022777
# pack_by_bins  a:sum     d:sum      a:sum            4.0  0.023399
#               a:maxdiff d:lnorm    d:maxratio       4.0  0.025125
#               pp        d:maxratio d:maxratio       4.0  0.030806
#               a:lnorm   d:lnorm    a:lnorm          4.0  0.034011
# pack_by_items a:sum     d:sum      a:sum            4.0  0.042389
#               a:lnorm   d:lnorm    a:lnorm          4.0  0.061780
#               pp        d:maxratio d:maxratio      10.2  0.056249
#               a:maxdiff d:lnorm    d:maxratio      13.4  0.044740
#
# class: 5, num_items: 100
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  none      none       none             7.0  0.049138
# pack_by_items none      none       none             7.0  0.088626
# pack_by_bins  a:sum     d:sum      a:sum            7.0  0.090005
#               a:maxdiff d:lnorm    d:maxratio       7.0  0.092593
#               pp        d:maxratio d:maxratio       7.0  0.114512
#               a:lnorm   d:lnorm    a:lnorm          7.0  0.127962
# pack_by_items a:sum     d:sum      a:sum            7.0  0.165541
#               a:lnorm   d:lnorm    a:lnorm          7.0  0.239346
#               pp        d:maxratio d:maxratio      14.6  0.216636
#               a:maxdiff d:lnorm    d:maxratio      20.2  0.172724
# class: 5, num_items: 200
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         13.1  0.498945
#               pp        d:maxratio d:maxratio      13.2  0.444436
#               a:maxdiff d:lnorm    d:maxratio      13.3  0.352767
# pack_by_items a:lnorm   d:lnorm    a:lnorm         13.4  0.947607
# pack_by_bins  a:sum     d:sum      a:sum           13.5  0.350365
# pack_by_items a:sum     d:sum      a:sum           13.5  0.655762
# pack_by_bins  none      none       none            13.7  0.192154
# pack_by_items none      none       none            13.7  0.348146
#               pp        d:maxratio d:maxratio      30.0  0.851920
#               a:maxdiff d:lnorm    d:maxratio      33.5  0.676303
#
# class: 6, num_items: 25
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum           12.2  0.006515
#               a:lnorm   d:lnorm    a:lnorm         12.2  0.008579
# pack_by_items a:sum     d:sum      a:sum           12.2  0.009622
#               a:lnorm   d:lnorm    a:lnorm         12.2  0.013301
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      13.1  0.007102
#               none      none       none            13.3  0.004504
# pack_by_items none      none       none            13.3  0.005829
# pack_by_bins  pp        d:maxratio d:maxratio      13.6  0.008304
# pack_by_items a:maxdiff d:lnorm    d:maxratio      13.9  0.010260
#               pp        d:maxratio d:maxratio      14.9  0.012915
#
# class: 6, num_items: 50
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum           22.6  0.025202
#               a:lnorm   d:lnorm    a:lnorm         22.6  0.033021
# pack_by_items a:sum     d:sum      a:sum           22.7  0.037317
#               a:lnorm   d:lnorm    a:lnorm         22.7  0.052412
# pack_by_bins  pp        d:maxratio d:maxratio      23.9  0.029856
#               none      none       none            24.4  0.016695
# pack_by_items none      none       none            24.4  0.022375
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      25.4  0.025741
# pack_by_items a:maxdiff d:lnorm    d:maxratio      25.6  0.039142
#               pp        d:maxratio d:maxratio      26.3  0.049912
#
# class: 6, num_items: 100
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         44.3  0.123686
#               a:sum     d:sum      a:sum           44.7  0.093929
# pack_by_items a:sum     d:sum      a:sum           44.7  0.144890
#               a:lnorm   d:lnorm    a:lnorm         44.7  0.202117
# pack_by_bins  pp        d:maxratio d:maxratio      47.5  0.109396
# pack_by_items a:maxdiff d:lnorm    d:maxratio      48.2  0.149397
# pack_by_bins  none      none       none            48.4  0.062412
# pack_by_items none      none       none            48.4  0.087154
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      49.3  0.096663
# pack_by_items pp        d:maxratio d:maxratio      49.5  0.191039
#
# class: 6, num_items: 200
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         86.8  0.473243
# pack_by_items a:lnorm   d:lnorm    a:lnorm         87.4  0.789588
# pack_by_bins  a:sum     d:sum      a:sum           87.6  0.366509
# pack_by_items a:sum     d:sum      a:sum           87.7  0.572226
#               a:maxdiff d:lnorm    d:maxratio      91.8  0.589823
# pack_by_bins  pp        d:maxratio d:maxratio      92.6  0.413622
# pack_by_items pp        d:maxratio d:maxratio      93.9  0.747047
# pack_by_bins  none      none       none            94.5  0.245963
# pack_by_items none      none       none            94.5  0.340252
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      96.9  0.372215
#
# class: 7, num_items: 25
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum           11.4  0.006836
# pack_by_items a:sum     d:sum      a:sum           11.4  0.009822
#               a:lnorm   d:lnorm    a:lnorm         11.4  0.013775
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         11.5  0.009115
#               a:maxdiff d:lnorm    d:maxratio      11.9  0.007194
#               none      none       none            12.2  0.004483
# pack_by_items none      none       none            12.2  0.005873
# pack_by_bins  pp        d:maxratio d:maxratio      12.9  0.008583
# pack_by_items pp        d:maxratio d:maxratio      13.5  0.013365
#               a:maxdiff d:lnorm    d:maxratio      14.0  0.010818
# class: 7, num_items: 50
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum           20.6  0.025605
# pack_by_items a:sum     d:sum      a:sum           20.6  0.037608
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         20.7  0.034380
# pack_by_items a:lnorm   d:lnorm    a:lnorm         20.7  0.053018
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      22.0  0.025770
#               none      none       none            22.5  0.015929
# pack_by_items none      none       none            22.5  0.022047
# pack_by_bins  pp        d:maxratio d:maxratio      23.3  0.029745
# pack_by_items a:maxdiff d:lnorm    d:maxratio      25.3  0.040128
#               pp        d:maxratio d:maxratio      26.8  0.051147
#
# class: 7, num_items: 100
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:sum     d:sum      a:sum           41.9  0.095704
# pack_by_items a:sum     d:sum      a:sum           41.9  0.143158
#               a:lnorm   d:lnorm    a:lnorm         41.9  0.199098
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         42.0  0.125710
#               a:maxdiff d:lnorm    d:maxratio      43.8  0.095332
#               none      none       none            44.2  0.060932
# pack_by_items none      none       none            44.2  0.085348
#               a:maxdiff d:lnorm    d:maxratio      45.8  0.149775
# pack_by_bins  pp        d:maxratio d:maxratio      46.9  0.111164
# pack_by_items pp        d:maxratio d:maxratio      47.9  0.196501
#
# class: 7, num_items: 200
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         82.5  0.490821
# pack_by_items a:lnorm   d:lnorm    a:lnorm         82.6  0.784662
# pack_by_bins  a:sum     d:sum      a:sum           82.8  0.374328
# pack_by_items a:sum     d:sum      a:sum           82.8  0.565955
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      85.1  0.364101
#               none      none       none            87.6  0.241566
# pack_by_items none      none       none            87.6  0.341325
#               a:maxdiff d:lnorm    d:maxratio      91.2  0.582055
# pack_by_bins  pp        d:maxratio d:maxratio      92.5  0.422959
# pack_by_items pp        d:maxratio d:maxratio      94.3  0.761386
#
# class: 8, num_items: 25
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  pp        d:maxratio d:maxratio      13.1  0.009063
# pack_by_items a:lnorm   d:lnorm    a:lnorm         13.2  0.014239
# pack_by_bins  a:sum     d:sum      a:sum           13.3  0.007132
# pack_by_items a:sum     d:sum      a:sum           13.3  0.010040
# pack_by_bins  none      none       none            13.6  0.004888
# pack_by_items none      none       none            13.6  0.005983
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         13.7  0.009775
#               a:maxdiff d:lnorm    d:maxratio      14.1  0.007844
# pack_by_items a:maxdiff d:lnorm    d:maxratio      14.8  0.010909
#               pp        d:maxratio d:maxratio      14.8  0.013341
#
# class: 8, num_items: 50
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  pp        d:maxratio d:maxratio      25.1  0.033424
# pack_by_items a:lnorm   d:lnorm    a:lnorm         25.2  0.053383
# pack_by_bins  a:sum     d:sum      a:sum           25.5  0.025852
# pack_by_items a:sum     d:sum      a:sum           25.5  0.038383
# pack_by_bins  none      none       none            26.2  0.017405
# pack_by_items none      none       none            26.2  0.022773
#               pp        d:maxratio d:maxratio      26.2  0.049269
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         27.4  0.035150
#               a:maxdiff d:lnorm    d:maxratio      28.2  0.027545
# pack_by_items a:maxdiff d:lnorm    d:maxratio      28.5  0.039907
#
# class: 8, num_items: 100
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  pp        d:maxratio d:maxratio      50.0  0.119148
# pack_by_items a:lnorm   d:lnorm    a:lnorm         50.0  0.203096
# pack_by_bins  none      none       none            50.5  0.064198
# pack_by_items none      none       none            50.5  0.085016
# pack_by_bins  a:sum     d:sum      a:sum           50.5  0.097186
# pack_by_items a:sum     d:sum      a:sum           50.5  0.145861
#               pp        d:maxratio d:maxratio      52.1  0.184809
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      52.6  0.100892
#               a:lnorm   d:lnorm    a:lnorm         53.1  0.129220
# pack_by_items a:maxdiff d:lnorm    d:maxratio      53.2  0.149184
# class: 8, num_items: 200
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  pp        d:maxratio d:maxratio     100.0  0.470511
# pack_by_items a:lnorm   d:lnorm    a:lnorm        100.0  0.809393
# pack_by_bins  a:sum     d:sum      a:sum          100.3  0.385437
# pack_by_items a:sum     d:sum      a:sum          100.3  0.581120
# pack_by_bins  none      none       none           100.9  0.256986
# pack_by_items none      none       none           100.9  0.337827
#               pp        d:maxratio d:maxratio     103.9  0.732767
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm        105.3  0.510021
# pack_by_items a:maxdiff d:lnorm    d:maxratio     107.0  0.595415
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio     107.2  0.393515
#
# class: 9, num_items: 25
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  pp        d:maxratio d:maxratio       8.0  0.008891
#               a:lnorm   d:lnorm    a:lnorm          8.0  0.009533
# pack_by_items a:lnorm   d:lnorm    a:lnorm          8.1  0.015137
# pack_by_bins  a:sum     d:sum      a:sum            8.2  0.006911
#               a:maxdiff d:lnorm    d:maxratio       8.2  0.007381
# pack_by_items a:sum     d:sum      a:sum            8.2  0.010593
# pack_by_bins  none      none       none             8.7  0.004337
# pack_by_items none      none       none             8.7  0.006147
#               pp        d:maxratio d:maxratio       9.3  0.014544
#               a:maxdiff d:lnorm    d:maxratio       9.6  0.011481
#
# class: 9, num_items: 50
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         14.6  0.033073
# pack_by_items a:lnorm   d:lnorm    a:lnorm         15.2  0.056165
# pack_by_bins  a:sum     d:sum      a:sum           15.3  0.024283
#               pp        d:maxratio d:maxratio      15.3  0.030814
# pack_by_items a:sum     d:sum      a:sum           15.3  0.039444
# pack_by_bins  none      none       none            15.6  0.015136
# pack_by_items none      none       none            15.6  0.022568
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      15.8  0.026039
# pack_by_items pp        d:maxratio d:maxratio      16.1  0.052296
#               a:maxdiff d:lnorm    d:maxratio      17.7  0.042048
#
# class: 9, num_items: 100
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         27.7  0.127257
#               a:sum     d:sum      a:sum           28.1  0.093989
# pack_by_items a:sum     d:sum      a:sum           28.1  0.154578
#               a:lnorm   d:lnorm    a:lnorm         28.4  0.216966
# pack_by_bins  pp        d:maxratio d:maxratio      28.5  0.114719
#               a:maxdiff d:lnorm    d:maxratio      28.9  0.095256
#               none      none       none            29.3  0.056866
# pack_by_items none      none       none            29.3  0.087739
#               pp        d:maxratio d:maxratio      31.9  0.203584
#               a:maxdiff d:lnorm    d:maxratio      34.8  0.162638
#
# class: 9, num_items: 200
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         54.3  0.492387
#               pp        d:maxratio d:maxratio      56.2  0.439698
# pack_by_items a:lnorm   d:lnorm    a:lnorm         56.3  0.856048
# pack_by_bins  a:sum     d:sum      a:sum           56.6  0.365243
# pack_by_items a:sum     d:sum      a:sum           56.6  0.607625
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      57.5  0.365078
#               none      none       none            58.4  0.221482
# pack_by_items none      none       none            58.4  0.343102
#               pp        d:maxratio d:maxratio      62.2  0.796441
#               a:maxdiff d:lnorm    d:maxratio      67.3  0.632732
#
# class: 10, num_items: 24
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  none      none       none             8.5  0.003992
# pack_by_items none      none       none             8.5  0.005493
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm          9.2  0.008908
#               a:sum     d:sum      a:sum            9.3  0.006496
# pack_by_items a:sum     d:sum      a:sum            9.3  0.009508
# pack_by_bins  pp        d:maxratio d:maxratio       9.4  0.008142
# pack_by_items a:lnorm   d:lnorm    a:lnorm          9.4  0.013204
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio       9.9  0.006910
# pack_by_items a:maxdiff d:lnorm    d:maxratio      10.5  0.010173
#               pp        d:maxratio d:maxratio      11.2  0.012816
# class: 10, num_items: 51
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  none      none       none            18.5  0.016359
# pack_by_items none      none       none            18.5  0.023129
# pack_by_bins  a:sum     d:sum      a:sum           19.2  0.026264
#               a:lnorm   d:lnorm    a:lnorm         19.2  0.035422
# pack_by_items a:sum     d:sum      a:sum           19.2  0.039999
#               a:lnorm   d:lnorm    a:lnorm         19.2  0.056558
# pack_by_bins  pp        d:maxratio d:maxratio      19.9  0.031619
#               a:maxdiff d:lnorm    d:maxratio      20.4  0.027246
# pack_by_items a:maxdiff d:lnorm    d:maxratio      21.2  0.042976
#               pp        d:maxratio d:maxratio      22.2  0.053820
#
# class: 10, num_items: 99
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  none      none       none            35.5  0.058830
# pack_by_items none      none       none            35.5  0.086080
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         36.3  0.123501
# pack_by_items a:lnorm   d:lnorm    a:lnorm         36.4  0.208497
# pack_by_bins  a:sum     d:sum      a:sum           36.5  0.093288
# pack_by_items a:sum     d:sum      a:sum           36.5  0.148059
# pack_by_bins  pp        d:maxratio d:maxratio      38.0  0.111230
# pack_by_items a:maxdiff d:lnorm    d:maxratio      38.6  0.152631
# pack_by_bins  a:maxdiff d:lnorm    d:maxratio      38.7  0.094147
# pack_by_items pp        d:maxratio d:maxratio      41.8  0.194594
#
# class: 10, num_items: 201
#                                                bincount   runtime
# pack          select    itemsort   binsort
# pack_by_bins  a:lnorm   d:lnorm    a:lnorm         71.8  0.503093
#               none      none       none            71.9  0.237174
# pack_by_items none      none       none            71.9  0.351286
# pack_by_bins  a:sum     d:sum      a:sum           72.0  0.381357
# pack_by_items a:sum     d:sum      a:sum           72.0  0.610264
#               a:lnorm   d:lnorm    a:lnorm         72.0  0.842421
#               a:maxdiff d:lnorm    d:maxratio      74.7  0.627998
# pack_by_bins  pp        d:maxratio d:maxratio      76.2  0.444797
#               a:maxdiff d:lnorm    d:maxratio      76.9  0.377820
# pack_by_items pp        d:maxratio d:maxratio      83.1  0.799920

# %%
# Out:
# <map object at 0x7f1eeaf3df10>
